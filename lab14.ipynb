# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# Example data in a dictionary
data = {
    'ID': [1, 2, 3, 4],
    'Text': [
        "I love programming in Python.",
        "Python is great for data science.",
        "Machine learning is a subset of artificial intelligence.",
        "Deep learning is a powerful tool in AI."
    ]
}

# Convert to a DataFrame
df = pd.DataFrame(data)

df
# Out:
#    ID                                               Text
# 0   1                      I love programming in Python.
# 1   2                  Python is great for data science.
# 2   3  Machine learning is a subset of artificial int...
# 3   4            Deep learning is a powerful tool in AI.

# %%
# Apply TF-IDF transformation (same as before)
tfidf = TfidfVectorizer(max_features=5)
tfidf_matrix = tfidf.fit_transform(df['Text'])

# Convert sparse matrix to DataFrame
tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=tfidf.get_feature_names_out())

# Join TF-IDF features with original DataFrame
df = pd.concat([df, tfidf_df], axis=1)

# View the result
df
# Out:
#    ID                                               Text      deep        in  \
# 0   1                      I love programming in Python.  0.000000  0.707107
# 1   2                  Python is great for data science.  0.000000  0.000000
# 2   3  Machine learning is a subset of artificial int...  0.000000  0.000000
# 3   4            Deep learning is a powerful tool in AI.  0.614226  0.484263
#
#          is  learning    python
# 0  0.000000  0.000000  0.707107
# 1  0.629228  0.000000  0.777221
# 2  0.629228  0.777221  0.000000
# 3  0.392053  0.484263  0.000000
